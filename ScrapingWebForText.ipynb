# %%
# Import packages
import requests
from bs4 import BeautifulSoup

# Specify url: url
url = 'https://sfbay.craigslist.org/eby/apa/d/vallejo-we-have-amazing-move-in/7043576696.html'

# Package the request, send the request and catch the response: r
r = requests.get(url)

# Extract the response as html: html_doc
html_doc = r.text

# Create a BeautifulSoup object from the HTML: soup
soup = BeautifulSoup(html_doc)

# Get the title of Guido's webpage: guido_title
guido_title = soup.title

# Print the title of Guido's webpage to the shell
print(guido_title)

# Get Guido's text: guido_text
guido_text = soup.get_text()

# Print Guido's text to the shell
print(guido_text)
# Out:
# <title>We have AMAZING Move-In Specials, Not even Santa can Compete - apts/housing for rent - apartment rent</title>
#
#
# We have AMAZING Move-In Specials, Not even Santa can Compete - apts/housing for rent - apartment rent
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!--
#     function C(k){return(document.cookie.match('(^|; )'+k+'=([^;]*)')||0)[2]}
#     var pagetype, pagemode;
#     (function(){
#         var h = document.documentElement;
#         h.className = h.className.replace('no-js', 'js');
#         var b = document.body;
#         var bodyClassList = b.className.split(/\s+/);;
#         pagetype = bodyClassList[0]; // dangerous assumption
#         var fmt = C('cl_fmt');
#         if ( fmt === 'regular' || fmt === 'mobile' ) {
#             pagemode = fmt;
#         } else if (screen.width <= 480) {
#             pagemode = 'mobile';
#         } else {
#             pagemode = 'regular';
#         }
#         pagemode = pagemode === 'mobile' ? 'mobile' : 'desktop';
#         bodyClassList.push(pagemode);
#         if (C('hidesearch') === '1' && pagemode !== 'mobile') {
#             bodyClassList.push('hide-search');
#         }
#         var width = window.innerWidth || document.documentElement.clientWidth;
#         if (width > 1000) { bodyClassList.push('w1024'); }
#         if (typeof window.sectionBase !== 'undefined') {
#             var mode = (decodeURIComponent(C('cl_tocmode') || '').match(new RegExp(window.sectionBase + ':([^,]+)', 'i')) || {})[1] || window.defaultView;
#             if (mode) {
#                 bodyClassList.push(mode);
#             }
#         }
#         b.className = bodyClassList.join(' ');
#     }());
# -->
#
#
#
#     try the craigslist app »
#
#         Android
#
#
#         iOS
#
#
#
# CL
#
#
#
#
# SF bay area
# >
#
#
#
#
# east bay
# >
#
#
#
#
# housing
# >
#
#
#
#
# apts/housing for rent
#
#
#
#
#
#
#
# post
#
#
# account
#
#
#
#
#
#  favorites
#
#
#
#
#
#
#
#
#
#
#
#
#  hidden
#
#
#
#
#
#
#
#
# CL
#
#
#
#
# east bay            >
#
# apts/housing for rent
#
#
#
# ...
#
#
#
#
#
# ◀  prev
# ▲
#  next ▶
#
#
#
#
#
#       reply
#
#
#
#
#
# favorite
#
#
#
# favorite
#
#
#
#
#
# hide
#
#
#
# unhide
#
#
#
#
#
# ⚐
# ⚑
#
#
#                 flag
#
#
#
# ⚑
#
#                 flagged
#
#
#
#
#
#                     Posted
#
#                         2019-12-23 12:27
#
#
#
#                 Contact Information:
#
# print
#
#
#
#
# $1885 / 2br - 1074ft2 - We have AMAZING Move-In Specials, Not even Santa can Compete (vallejo / benicia)
#
#
#
#
# <
# image 1 of 17
# >
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!--
# var imgList = [{"shortid":"2KQmWjr6sMF","url":"https://images.craigslist.org/00Q0Q_2KQmWjr6sMF_600x450.jpg","thumb":"https://images.craigslist.org/00Q0Q_2KQmWjr6sMF_50x50c.jpg","imgid":"1:00Q0Q_2KQmWjr6sMF"},{"shortid":"blKS2UHveo7","url":"https://images.craigslist.org/00N0N_blKS2UHveo7_600x450.jpg","thumb":"https://images.craigslist.org/00N0N_blKS2UHveo7_50x50c.jpg","imgid":"1:00N0N_blKS2UHveo7"},{"shortid":"bfieF0OpIXc","url":"https://images.craigslist.org/00E0E_bfieF0OpIXc_600x450.jpg","thumb":"https://images.craigslist.org/00E0E_bfieF0OpIXc_50x50c.jpg","imgid":"1:00E0E_bfieF0OpIXc"},{"shortid":"a3Jr0TB6XsJ","url":"https://images.craigslist.org/00j0j_a3Jr0TB6XsJ_600x450.jpg","thumb":"https://images.craigslist.org/00j0j_a3Jr0TB6XsJ_50x50c.jpg","imgid":"1:00j0j_a3Jr0TB6XsJ"
.org/00j0j_5bYyfR9NOxr_50x50c.jpg","imgid":"1:00j0j_5bYyfR9NOxr"},{"shortid":"fJ2X27l63Rl","url":"https://images.craigslist.org/00909_fJ2X27l63Rl_600x450.jpg","thumb":"https://images.craigslist.org/00909_fJ2X27l63Rl_50x50c.jpg","imgid":"1:00909_fJ2X27l63Rl"},{"shortid":"jpVbQNZW9zD","url":"https://images.craigslist.org/00M0M_jpVbQNZW9zD_600x450.jpg","thumb":"https://images.craigslist.org/00M0M_jpVbQNZW9zD_50x50c.jpg","imgid":"1:00M0M_jpVbQNZW9zD"}];
# -->
#
#
#
#
# 1101 N Camino Alto, near Sereno Dr.
#
#
#         (google map)
#
#
#
#
# 2BR / 2Ba
# 1074ft2
# available dec 23
#
#
# cats are OK - purrr
#
# dogs are OK - wooof
#
# apartment
#
# laundry on site
#
# no smoking
#
# carport
#
#
#
#
#
# QR Code Link to This Post
#
#
#  Featuring Luxuriously Remodeled Interiors  CALL:  show contact info
#  x156  $1,559  . 1 Bed 1 Bath . 780 Sq.Ft  Available NowAvailable Now The Valencia Website: http://www.thevalenciaapartments.com/Home.aspxAddress:  1101 North Camino Alto Vallejo, CA 94589 Want more information? http://unit-availability.com/lead/3m1517113869/floorplan/1763444/1?extnId=8901983 DESCRIPTION  Take a look at this one-bedroom, one-bathroom apartment at Valencia. In the home you will find new flooring, an equipped kitchen, and central air conditioning system. Contact the staff today for more information.  FLOORPLAN/UNIT   FEATURES  Central Heating and Air  Wood Burning Fireplaces in Downstairs Units  Stainless Steel Appliances with Built in Microwave  Upgraded Maple Cabinets  Modern Kitchens with Granite Countertops  Private Patios or Balconies  Vaulted Ceiling in Upstairs Units  Premium Lighting  Dual Pane Windows  LEASE  TERMS  3 - 13 months  OFFICE   HOURS Monday 9:00am to 5:00pm Tuesday 9:00am to 5:00pm Wednesday 9:00am to 5:00pm Thursday 9:00am to 5:00pm Friday 9:00am to 5:00pmCALL US TODAY!  show contact info
#  x156 Equal Housing Opportunity
#
# do NOT contact me with unsolicited services or offers
#
#
# post id: 7043576696
# posted: 2019-12-23 12:27
#
# email to friend
#
#
#
# ♥ best of
#  [?]
#
#
#
#
#
#
#
#
#     Please flag
#     discriminatory housing ads
#
#
# Avoid scams, deal locally!
# DO NOT wire funds (e.g. Western Union), or buy/rent sight unseen
#
#
#
#
#
# ©  craigslistCL
# help
# safety
# privacy
# feedback
# cl jobs
# termsnew
# about
# mobile
# desktop
#
#
#
# <!--
# var countOfTotalText = "image {count} of {total}";
# var imageConfig = {"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};
# var maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";
# var pID = 7043576696;
# -->
#
#                 try {
#                     if (
#                         !/\/\/.+\.craigslist\.org\/about\//.test(window.location.href)
#                         &&
#                         (!window.addEventListener || JSON.parse(JSON.stringify('x')) !== 'x')
#                     ) {
#                         throw "unsupported browser";
#                     }
#                 } catch (e) {
#                     function cleanup() {
#                         document.body.innerHTML = '<div id="cl-unsupported-browser" style="margin:1em;font-size:150%;text-align:center;">We have detected you are using a browser that is missing critical features.<br><br>Please visit craigslist from a modern browser.</div>';
#                         document.body.style = "display:block";
#                     }
#
#                     try {
#                         document.body.style = "display:none";
#                     } catch (e) {
#                     }
#                     window.onload = cleanup;
#                     window.clUnsupportedBrowser = true;
#                 }
